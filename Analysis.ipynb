# %% [markdown]
# # Process
#
# Data Cleaning:
#
# Data Visualization:
#
# Model Selection and Building:
#
# Model Evaluation and Hyperparameter Tuning:
#
# Prediction:
#
# Interactive Geo Maps:

# %%
import pandas as pd


file_paths = {
    "Anthrax": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Anthrax.csv',
    "Antimicrobial_resistance": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Antimicrobial_resistance.csv',
    "Arenavirus_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Arenavirus_infection.csv',
    "Botulism": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Botulism.csv',
    "Brucellosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Brucellosis.csv',
    "Campylobacteriosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Campylobacteriosis.csv',
    "Chikungunya_virus_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chikungunya_virus_disease.csv',
    "Chlamydia_infection_lymphogranuloma_venereum": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chlamydia_infection _lymphogranuloma_venereum.csv',
    "Chlamydia_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chlamydia_infection.csv',
    "Cholera": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Cholera.csv',
    "Creutzfeldt-Jakob_disease_variant": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Creutzfeldt-Jakob_disease _variant.csv',
    "Crimean-Congo_haemorrhagic_fever": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Crimean-Congo_haemorrhagic_fever.csv',
    "Cryptosporidiosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Cryptosporidiosis.csv',
    "Dengue": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Dengue.csv',
    "Diphtheria": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Diphtheria.csv',
    "Ebola_and_Marburg_virus_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Ebola_and_Marburg_virus_disease.csv',
    "Echinococcosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Echinococcosis.csv',
    "Giardiasis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Giardiasis.csv',
    "Gonorrhoea": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Gonorrhoea.csv',
    "Hantavirus_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Gonorrhoea.csv',
    "Healthcare-associated_infections_surgical_site": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Healthcare-associated_infections__surgical_site_infections.csv',
    "Healthcare-associated_infections_intensive_care": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Healthcare-associated_infections_in_intensive_care_units.csv',
    "Hepatitis_A": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_A.csv',
    "Hepatitis_B": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_B.csv',
    "Hepatitis_C": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_C.csv',
    "HIV_infection_and_AIDS": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_HIV_infection_and_AIDS.csv',
    "Influenza": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Influenza.csv',
    "Invasive_Haemophilus_influenzae_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_Haemophilus_influenzae_disease.csv',
    "Invasive_meningococcal_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_meningococcal_disease.csv',
    "Invasive_pneumococcal_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_pneumococcal_disease.csv',
    "Legionnaires_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Legionnaires__disease.csv',
    "Leptospirosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Leptospirosis.csv',
    "Listeriosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Listeriosis.csv',
    "Lyme_Neuroborreliosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Lyme_Neuroborreliosis.csv',
    "Malaria": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Malaria.csv',
    "Mumps": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Mumps.csv',
    "Other_Viral_Haemorrhagic_fevers": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Other_Viral_Haemorrhagic_fevers.csv',
    "Pertussis" : r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Pertussis.csv',
    "Plague": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Plague.csv',
    "Q_fever": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Q_fever.csv',
    "Rabies": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rabies.csv",
    "Respiratory_Syncytial_Virus": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Respiratory_Syncytial_Virus_.csv",
    "Rift_valley_fever": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rift_valley_fever.csv",
    "Rubella": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rubella.csv",
    "Shigellosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Shigellosis.csv",
    "STEC_VTEC_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_STEC_VTEC_infection.csv",
    "Syphilis_congenital": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Syphilis _congenital.csv",
    "Syphilis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Syphilis.csv",
    "Tetanus": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tetanus.csv",
    "Tick-borne_encephalitis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tick-borne_encephalitis.csv",
    "Tularaemia": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tularaemia.csv",
    "West_Nile_virus_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_West_Nile_virus_infection.csv",
    "Yellow_fever": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Yellow_fever.csv",
    "Yersiniosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Yersiniosis.csv",
    "Zika_virus_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Zika_virus_infection.csv",
    "Toxoplasmosis_congenital": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Toxoplasmosis _congenital.csv",
    "Trichinellosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Trichinellosis.csv",
    "Tuberculosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tuberculosis.csv"
}

# Read each dataset into a dictionary
datasets = {name: pd.read_csv(path) for name, path in file_paths.items()}

# Display the first few rows of each dataset to understand their structure
datasets_overview = {name: data.head() for name, data in datasets.items()}

# Display the information of each dataset
datasets_info = {name: data.info() for name, data in datasets.items()}

datasets_overview, datasets_info
# Out:
# C:\Users\aruka\AppData\Local\Temp\ipykernel_21720\219463473.py:66: DtypeWarning:
#
# Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HealthTopic  1074 non-null   object
#  1   Population   1074 non-null   object
#  2   Indicator    1074 non-null   object
#  3   Unit         1074 non-null   object
#  4   Time         1074 non-null   int64
#  5   RegionCode   1074 non-null   object
#  6   RegionName   1074 non-null   object
#  7   NumValue     1074 non-null   object
#  8   TxtValue     0 non-null      float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 75.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85215 entries, 0 to 85214
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %% [markdown]
# The datasets have been successfully loaded. Here's an overview of the data:
#
# All datasets contain similar columns such as HealthTopic, Population, Indicator, Unit, Time, RegionCode, RegionName, NumValue, and TxtValue.
# TxtValue is consistently null across all datasets and will be removed.
# NumValue is sometimes non-numeric (e.g., '-') and will need to be cleaned and converted.
#
# # Steps for Cleaning:
#
# Remove the TxtValue column since it's empty.
#
# Convert NumValue to numeric, handling or removing non-numeric values.
#
# General Cleanup for any other data inconsistencies.

# %%
import pandas as pd

# Dictionary of file paths
file_paths = {
    "Anthrax": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Anthrax.csv',
    "Antimicrobial_resistance": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Antimicrobial_resistance.csv',
    "Arenavirus_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Arenavirus_infection.csv',
    "Botulism": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Botulism.csv',
    "Brucellosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Brucellosis.csv',
    "Campylobacteriosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Campylobacteriosis.csv',
    "Chikungunya_virus_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chikungunya_virus_disease.csv',
    "Chlamydia_infection_lymphogranuloma_venereum": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chlamydia_infection _lymphogranuloma_venereum.csv',
    "Chlamydia_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Chlamydia_infection.csv',
    "Cholera": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Cholera.csv',
    "Creutzfeldt-Jakob_disease_variant": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Creutzfeldt-Jakob_disease _variant.csv',
    "Crimean-Congo_haemorrhagic_fever": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Crimean-Congo_haemorrhagic_fever.csv',
    "Cryptosporidiosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Cryptosporidiosis.csv',
    "Dengue": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Dengue.csv',
    "Diphtheria": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Diphtheria.csv',
    "Ebola_and_Marburg_virus_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Ebola_and_Marburg_virus_disease.csv',
    "Echinococcosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Echinococcosis.csv',
    "Giardiasis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Giardiasis.csv',
    "Gonorrhoea": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Gonorrhoea.csv',
    "Hantavirus_infection": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Gonorrhoea.csv',
    "Healthcare-associated_infections_surgical_site": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Healthcare-associated_infections__surgical_site_infections.csv',
    "Healthcare-associated_infections_intensive_care": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Healthcare-associated_infections_in_intensive_care_units.csv',
    "Hepatitis_A": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_A.csv',
    "Hepatitis_B": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_B.csv',
    "Hepatitis_C": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Hepatitis_C.csv',
    "HIV_infection_and_AIDS": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_HIV_infection_and_AIDS.csv',
    "Influenza": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Influenza.csv',
    "Invasive_Haemophilus_influenzae_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_Haemophilus_influenzae_disease.csv',
    "Invasive_meningococcal_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_meningococcal_disease.csv',
    "Invasive_pneumococcal_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Invasive_pneumococcal_disease.csv',
    "Legionnaires_disease": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Legionnaires__disease.csv',
    "Leptospirosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Leptospirosis.csv',
    "Listeriosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Listeriosis.csv',
    "Lyme_Neuroborreliosis": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Lyme_Neuroborreliosis.csv',
    "Malaria": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Malaria.csv',
    "Mumps": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Mumps.csv',
    "Other_Viral_Haemorrhagic_fevers": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Other_Viral_Haemorrhagic_fevers.csv',
    "Pertussis" : r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Pertussis.csv',
    "Plague": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Plague.csv',
    "Q_fever": r'D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Q_fever.csv',
    "Rabies": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rabies.csv",
    "Respiratory_Syncytial_Virus": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Respiratory_Syncytial_Virus_.csv",
    "Rift_valley_fever": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rift_valley_fever.csv",
    "Rubella": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Rubella.csv",
    "Shigellosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Shigellosis.csv",
    "STEC_VTEC_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_STEC_VTEC_infection.csv",
    "Syphilis_congenital": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Syphilis _congenital.csv",
    "Syphilis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Syphilis.csv",
    "Tetanus": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tetanus.csv",
    "Tick-borne_encephalitis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tick-borne_encephalitis.csv",
    "Tularaemia": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tularaemia.csv",
    "West_Nile_virus_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_West_Nile_virus_infection.csv",
    "Yellow_fever": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Yellow_fever.csv",
    "Yersiniosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Yersiniosis.csv",
    "Zika_virus_infection": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Zika_virus_infection.csv",
    "Toxoplasmosis_congenital": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Toxoplasmosis _congenital.csv",
    "Trichinellosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Trichinellosis.csv",
    "Tuberculosis": r"D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Tuberculosis.csv"
}


# List to hold data from each CSV
dataframes = []

# Loop through the dictionary, reading each CSV file
for disease, file_path in file_paths.items():
    df = pd.read_csv(file_path)
    # Add a column to each dataframe to identify the disease
    df['Disease'] = disease
    dataframes.append(df)

# Concatenate all dataframes into a single dataframe
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_df.to_csv('D:/combined_dataset.csv', index=False)

print("All files have been combined into a single dataset.")
# Out:
# C:\Users\aruka\AppData\Local\Temp\ipykernel_21720\951044496.py:71: DtypeWarning:
#
# Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
# All files have been combined into a single dataset.

# %%
# Function to clean individual datasets
def clean_dataset(df):
    # Drop TxtValue column since it's entirely null
    df = df.drop(columns=["TxtValue"], errors='ignore')
    
    # Convert NumValue to numeric, setting errors to NaN and then dropping these rows
    df['NumValue'] = pd.to_numeric(df['NumValue'], errors='coerce')
    df = df.dropna(subset=['NumValue'])
    
    return df

# Apply cleaning function to each dataset
datasets_cleaned = {name: clean_dataset(data) for name, data in datasets.items()}

# Check the cleaned data for one of the datasets
cleaned_data_example = datasets_cleaned['Anthrax'].head()

cleaned_data_example
# Out:
#   HealthTopic       Population       Indicator Unit  Time RegionCode  \
# 0     Anthrax  Confirmed cases  Reported cases    N  2007         AT
# 1     Anthrax  Confirmed cases  Reported cases    N  2007         BE
# 2     Anthrax  Confirmed cases  Reported cases    N  2007         BG
# 3     Anthrax  Confirmed cases  Reported cases    N  2007         CY
# 4     Anthrax  Confirmed cases  Reported cases    N  2007         CZ
#
#   RegionName  NumValue
# 0    Austria       0.0
# 1    Belgium       0.0
# 2   Bulgaria       1.0
# 3     Cyprus       0.0
# 4    Czechia       0.0

# %%
# Applying the cleaning function to each dataset and showing the cleaned examples for each
cleaned_data_examples = {name: clean_dataset(data).head() for name, data in datasets.items()}

cleaned_data_examples
# Out:
# {'Anthrax':   HealthTopic       Population       Indicator Unit  Time RegionCode  \
#  0     Anthrax  Confirmed cases  Reported cases    N  2007         AT
#  1     Anthrax  Confirmed cases  Reported cases    N  2007         BE
#  2     Anthrax  Confirmed cases  Reported cases    N  2007         BG
#  3     Anthrax  Confirmed cases  Reported cases    N  2007         CY
#  4     Anthrax  Confirmed cases  Reported cases    N  2007         CZ
#
#    RegionName  NumValue
#  0    Austria       0.0
#  1    Belgium       0.0
#  2   Bulgaria       1.0
#  3     Cyprus       0.0
#  4    Czechia       0.0  ,
#  'Antimicrobial_resistance':                 HealthTopic                          Population  \
#  0  Antimicrobial resistance  Acinetobacter spp.|Aminoglycosides
#  1  Antimicrobial resistance  Acinetobacter spp.|Aminoglycosides
#  2  Antimicrobial resistance  Acinetobacter spp.|Aminoglycosides
#  3  Antimicrobial resistance  Acinetobacter spp.|Aminoglycosides
# ...

# %%
# import plotly.express as px

# # Function to create interactive time series plots for each disease
# def plotly_cases_over_time(data, name):
#     summary_time = data.groupby('Time')['NumValue'].sum().reset_index()
#     fig = px.line(summary_time, x='Time', y='NumValue', title=f'Total {name} Cases Over Time')
#     fig.update_xaxes(title_text='Year')
#     fig.update_yaxes(title_text='Total Cases')
#     fig.show()

# # Function to create interactive bar charts for top regions in each disease dataset
# def plotly_cases_by_region(data, name):
#     summary_region = data.groupby('RegionName')['NumValue'].sum().sort_values(ascending=False).head(10).reset_index()
#     fig = px.bar(summary_region, x='RegionName', y='NumValue', title=f'Top 10 Regions for {name} Cases')
#     fig.update_xaxes(title_text='Region')
#     fig.update_yaxes(title_text='Total Cases')
#     fig.show()

# # Apply the plotting functions to each dataset
# for name, data in datasets_cleaned.items():
#     plotly_cases_over_time(data, name)
#     plotly_cases_by_region(data, name)

# %%
import pandas as pd
import plotly.express as px

# Combine all datasets into one for time series analysis
all_data_combined = pd.concat(datasets_cleaned.values())

# Aggregate data over time across all diseases
total_cases_over_time = all_data_combined.groupby(['Time', 'HealthTopic'])['NumValue'].sum().reset_index()

# Create a Plotly line plot for total cases over time across all diseases
fig_time = px.line(total_cases_over_time, x='Time', y='NumValue', color='HealthTopic', 
                   title='Total Cases Over Time Across All Diseases',
                   labels={'NumValue': 'Total Cases', 'Time': 'Year', 'HealthTopic': 'Disease'})
fig_time.show()

# Aggregate data by region across all diseases
total_cases_by_region = all_data_combined.groupby(['RegionName', 'HealthTopic'])['NumValue'].sum().reset_index()

# Create a Plotly bar plot for total cases by region across all diseases
fig_region = px.bar(total_cases_by_region, x='RegionName', y='NumValue', color='HealthTopic',
                    title='Total Cases by Region Across All Diseases',
                    labels={'NumValue': 'Total Cases', 'RegionName': 'Region', 'HealthTopic': 'Disease'},
                    category_orders={"RegionName": total_cases_by_region.sort_values(by='NumValue', ascending=False)['RegionName'].unique()})
fig_region.show()
