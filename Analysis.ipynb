# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:\VIT AP\FALL SEMESTER 2024\Epi-Tracker---AI-assisted-Real-time-Disease-Outbreak-Detection-and-Tracking\Datasets\ECDC_surveillance_data_Anthrax.csv')
df
# Out:
#      HealthTopic                      Population         Indicator Unit  Time  \
# 0        Anthrax                 Confirmed cases    Reported cases    N  2007
# 1        Anthrax                 Confirmed cases    Reported cases    N  2007
# 2        Anthrax                 Confirmed cases    Reported cases    N  2007
# 3        Anthrax                 Confirmed cases    Reported cases    N  2007
# 4        Anthrax                 Confirmed cases    Reported cases    N  2007
# ...          ...                             ...               ...  ...   ...
# 1069     Anthrax  Confirmed cases - Data quality  Completeness Age    %  2022
# 1070     Anthrax  Confirmed cases - Data quality  Completeness Age    %  2022
# 1071     Anthrax  Confirmed cases - Data quality  Completeness Age    %  2022
# 1072     Anthrax  Confirmed cases - Data quality  Completeness Age    %  2022
# 1073     Anthrax  Confirmed cases - Data quality  Completeness Age    %  2022
#
# ...

# %%
df.shape
# Out:
# (1074, 9)
